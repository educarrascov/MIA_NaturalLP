# %% [markdown]
# **RECONOCIMIENTO Y SÍNTESIS DE VOZ**
#
# *John Atkinson*
#
# Este programa utiliza servicios pre-entrenados de Google para *reconocimiento automático de  voz* (ASR) y *síntesis de texto a voz* (TTS) en Español.
#
# *   El módulo de ASR utiliza el servicio [SpeechRecognition](https://realpython.com/python-speech-recognition/). Note que *Google Colab* no puede procesar el dispositivo de audio directamente (i.e., micrófono) por lo que se realizó unos pequeños ajustes invocando a rutinas en JavaScript.
#
# *   El módulo de TTS utiliza el servicio [gTTS](https://gtts.readthedocs.io/en/latest/module.html).
#
# Primero, necesitamos instalar algunos paquetes:

# %%
apt install libasound2-dev portaudio19-dev libportaudio2 libportaudiocpp0 ffmpeg
pip install speechrecognition
pip install PyAudio
pip -q install pydub
pip install gtts
pip install pygobject
# Out:
# The operation couldn’t be completed. Unable to locate a Java Runtime that supports apt.
# Please visit http://www.java.com for information on installing Java.
#
# Collecting speechrecognition
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      |████████████████████████████████| 32.8 MB 239 kB/s eta 0:00:011     |▊                               | 778 kB 3.3 MB/s eta 0:00:10     |█▋                              | 1.6 MB 3.3 MB/s eta 0:00:10     |███▏                            | 3.3 MB 3.3 MB/s eta 0:00:09     |█████████████████████▉          | 22.4 MB 48.8 MB/s eta 0:00:01     |██████████████████████▋         | 23.2 MB 48.8 MB/s eta 0:00:01     |███████████████████████▌        | 24.1 MB 48.8 MB/s eta 0:00:01
# Installing collected packages: speechrecognition
# Successfully installed speechrecognition-3.8.1
# Collecting PyAudio
#   Downloading PyAudio-0.2.11.tar.gz (37 kB)
# Building wheels for collected packages: PyAudio
#   Building wheel for PyAudio (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-ciehy0w0/pyaudio_ede4e193defb45eb8befd6aa3c4a2d50/setup.py'"'"'; __file__='"'"'/private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-ciehy0w0/pyaudio_ede4e193defb45eb8befd6aa3c4a2d50/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-wheel-mrhc6te_
#        cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-ciehy0w0/pyaudio_ede4e193defb45eb8befd6aa3c4a2d50/
#   Complete output (18 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-universal2-3.9
#   copying src/pyaudio.py -> build/lib.macosx-10.9-universal2-3.9
#   warning: build_py: byte-compiling is disabled, skipping.
#
#   running build_ext
#   building '_portaudio' extension
#   creating build/temp.macosx-10.9-universal2-3.9
#   creating build/temp.macosx-10.9-universal2-3.9/src
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch arm64 -arch x86_64 -g -DMACOSX=1 -I/Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/include -I/Library/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c src/_portaudiomodule.c -o build/temp.macosx-10.9-universal2-3.9/src/_portaudiomodule.o
#   src/_portaudiomodule.c:29:10: fatal error: 'portaudio.h' file not found
#   #include "portaudio.h"
#            ^~~~~~~~~~~~~
#   1 error generated.
#   error: command '/usr/bin/gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for PyAudio
#   Running setup.py clean for PyAudio
# Failed to build PyAudio
# Installing collected packages: PyAudio
#     Running setup.py install for PyAudio ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-ciehy0w0/pyaudio_ede4e193defb45eb8befd6aa3c4a2d50/setup.py'"'"'; __file__='"'"'/private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-ciehy0w0/pyaudio_ede4e193defb45eb8befd6aa3c4a2d50/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-record-g0i2nvg6/install-record.txt --single-version-externally-managed --compile --install-headers /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/include/site/python3.9/PyAudio
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-ciehy0w0/pyaudio_ede4e193defb45eb8befd6aa3c4a2d50/
#     Complete output (18 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     copying src/pyaudio.py -> build/lib.macosx-10.9-universal2-3.9
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     building '_portaudio' extension
#     creating build/temp.macosx-10.9-universal2-3.9
#     creating build/temp.macosx-10.9-universal2-3.9/src
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch arm64 -arch x86_64 -g -DMACOSX=1 -I/Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/include -I/Library/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c src/_portaudiomodule.c -o build/temp.macosx-10.9-universal2-3.9/src/_portaudiomodule.o
#     src/_portaudiomodule.c:29:10: fatal error: 'portaudio.h' file not found
#     #include "portaudio.h"
#              ^~~~~~~~~~~~~
#     1 error generated.
#     error: command '/usr/bin/gcc' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-ciehy0w0/pyaudio_ede4e193defb45eb8befd6aa3c4a2d50/setup.py'"'"'; __file__='"'"'/private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-ciehy0w0/pyaudio_ede4e193defb45eb8befd6aa3c4a2d50/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-record-g0i2nvg6/install-record.txt --single-version-externally-managed --compile --install-headers /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/include/site/python3.9/PyAudio Check the logs for full command output.
# Collecting gtts
#   Downloading gTTS-2.2.3-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from gtts) (2.26.0)
# Requirement already satisfied: six in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from gtts) (1.16.0)
# Collecting click
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from requests->gtts) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from requests->gtts) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from requests->gtts) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/lib/python3.9/site-packages (from requests->gtts) (2021.5.30)
# Installing collected packages: click, gtts
# Successfully installed click-8.0.1 gtts-2.2.3
# Collecting pygobject
#   Downloading PyGObject-3.40.1.tar.gz (714 kB)
#      |████████████████████████████████| 714 kB 2.5 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-qr_j8k06/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-kv9dr4cu/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (37 lines):
#   Collecting setuptools
#     Downloading setuptools-58.0.2-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Downloading pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmpyuzdx7ie_in_process.py build_wheel /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmp5sj9e1jw
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-98keudv7/pycairo_78b1ba2362b4493b98dd513b49d94c7d
#     Complete output (14 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     creating build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.py -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.pyi -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/py.typed -> build/lib.macosx-10.9-universal2-3.9/cairo
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     'pkg-config' not found.
#     Command ['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/51/2f/4d5d5afb7000b9151e33952b59163c9389bd867ac6fe85d62f85831fa061/PyGObject-3.40.1.tar.gz#sha256=6fb599aa59ceb9dd05fafb0d72b3862943e7d5e85c8ef6c74856bc6d4321cbab (from https://pypi.org/simple/pygobject/) (requires-python:>=3.6, <4). Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-qr_j8k06/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-kv9dr4cu/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Downloading PyGObject-3.40.0.tar.gz (714 kB)
#      |████████████████████████████████| 714 kB 30.7 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-tsfy_jje/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-ldv9tefo/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (37 lines):
#   Collecting setuptools
#     Using cached setuptools-58.0.2-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmpxvy4d026_in_process.py build_wheel /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmp7_zqprrm
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-yvcnyl2f/pycairo_ec5a914a2c2b4e6eab2d22948b496294
#     Complete output (14 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     creating build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.py -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.pyi -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/py.typed -> build/lib.macosx-10.9-universal2-3.9/cairo
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     'pkg-config' not found.
#     Command ['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/fa/0cfaa64ad7a4cd94fd74b698fcc8987ed780fce1651fecc6604f86f604cd/PyGObject-3.40.0.tar.gz#sha256=98d83f71e6313dadc29793450fec23b2eaa5c3f1c4b073d0a4f9c31b5cdb5fca (from https://pypi.org/simple/pygobject/) (requires-python:>=3.6, <4). Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-tsfy_jje/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-ldv9tefo/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Downloading PyGObject-3.38.0.tar.gz (712 kB)
#      |████████████████████████████████| 712 kB 19.2 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-ktsnlpnl/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-b0ec75xe/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (37 lines):
#   Collecting setuptools
#     Using cached setuptools-58.0.2-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmpa4y_ag1u_in_process.py build_wheel /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmpjig1xpz3
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-mezfizll/pycairo_00d69065b2144fcca2d20617a23d85dd
#     Complete output (14 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     creating build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.py -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.pyi -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/py.typed -> build/lib.macosx-10.9-universal2-3.9/cairo
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     'pkg-config' not found.
#     Command ['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/a7/de282a4aaedba59d60a895a7821e6497b39cbdfa94a352776ff45ffc6e6f/PyGObject-3.38.0.tar.gz#sha256=051b950f509f2e9f125add96c1493bde987c527f7a0c15a1f7b69d6d1c3cd8e6 (from https://pypi.org/simple/pygobject/) (requires-python:>=3.5, <4). Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-ktsnlpnl/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-b0ec75xe/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Downloading PyGObject-3.36.1.tar.gz (716 kB)
#      |████████████████████████████████| 716 kB 6.7 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-evq0vbg5/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-okz783r8/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (37 lines):
#   Collecting setuptools
#     Using cached setuptools-58.0.2-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmpbvran0ty_in_process.py build_wheel /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmphz_gjebj
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-jbs681w7/pycairo_640e2f6947164fdfb0ed6d0d9e3a456b
#     Complete output (14 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     creating build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.py -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.pyi -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/py.typed -> build/lib.macosx-10.9-universal2-3.9/cairo
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     'pkg-config' not found.
#     Command ['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/93/41/bf9ab8929f51dac2979ae81bb094728bacee3ceb049def72d3fc1bcb4241/PyGObject-3.36.1.tar.gz#sha256=012a589aec687bfa809a1ff9f5cd775dc7f6fcec1a6bc7fe88e1002a68f8ba34 (from https://pypi.org/simple/pygobject/) (requires-python:>=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, !=3.4.*, <4). Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-evq0vbg5/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-okz783r8/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Downloading PyGObject-3.36.0.tar.gz (714 kB)
#      |████████████████████████████████| 714 kB 34.6 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-ocq5wntl/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-15oen2dv/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (37 lines):
#   Collecting setuptools
#     Using cached setuptools-58.0.2-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmpr64o_3v8_in_process.py build_wheel /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmp886emrfi
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-yr08rnao/pycairo_835141078d1e47b8bfa0d5eba763acdf
#     Complete output (14 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     creating build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.py -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.pyi -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/py.typed -> build/lib.macosx-10.9-universal2-3.9/cairo
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     'pkg-config' not found.
#     Command ['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3e/b5/f4fd3351ed074aeeae30bff71428f38bc42187e34c44913239a9dc85a7fc/PyGObject-3.36.0.tar.gz#sha256=b97f570e55017fcd3732164811f24ecf63983a4834f61b55b0aaf64ecefac856 (from https://pypi.org/simple/pygobject/) (requires-python:>=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, !=3.4.*, <4). Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-ocq5wntl/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-15oen2dv/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Downloading PyGObject-3.34.0.tar.gz (699 kB)
#      |████████████████████████████████| 699 kB 12.7 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-4xo8wta7/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-9rb8s3ye/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (37 lines):
#   Collecting setuptools
#     Using cached setuptools-58.0.2-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmph5erxity_in_process.py build_wheel /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmppt1p43tu
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-ndi0k4cy/pycairo_eb36fc960fa04f16b0da6880c76f9cdc
#     Complete output (14 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     creating build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.py -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.pyi -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/py.typed -> build/lib.macosx-10.9-universal2-3.9/cairo
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     'pkg-config' not found.
#     Command ['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/8a/b183f3edc812d4d28c8b671a922b5bc2863be5d38c56b3ad9155815e78dd/PyGObject-3.34.0.tar.gz#sha256=2acb0daf2b3a23a90f52066cc23d1053339fee2f5f7f4275f8baa3704ae0c543 (from https://pypi.org/simple/pygobject/) (requires-python:>=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, !=3.4.*, <4). Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-4xo8wta7/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-9rb8s3ye/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Downloading PyGObject-3.32.2.tar.gz (698 kB)
#      |████████████████████████████████| 698 kB 39.9 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-w9mkdiyy/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-454g2l20/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (37 lines):
#   Collecting setuptools
#     Using cached setuptools-58.0.2-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmpbssmny4g_in_process.py build_wheel /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmp_hb3l6cz
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-nrnwp7ih/pycairo_3dd579530f764517aa145bcf849158d1
#     Complete output (14 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     creating build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.py -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.pyi -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/py.typed -> build/lib.macosx-10.9-universal2-3.9/cairo
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     'pkg-config' not found.
#     Command ['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/40/ee/8daf797cda4ffe7724b9d47cbb5e2b44ca6235764622d163c586bd9bd7c5/PyGObject-3.32.2.tar.gz#sha256=fa82746df059b9e0dcf473e0a9ff0693aa5e064f1ca1e2c46b5ac815bceda1ad (from https://pypi.org/simple/pygobject/) (requires-python:>=2.7, !=3.0.*, !=3.1.*, !=3.2.*, !=3.3.*, !=3.4.*, <4). Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-w9mkdiyy/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-454g2l20/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Downloading PyGObject-3.32.1.tar.gz (698 kB)
#      |████████████████████████████████| 698 kB 6.8 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-tf2ly0uj/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-dkaop06g/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (37 lines):
#   Collecting setuptools
#     Using cached setuptools-58.0.2-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmp1a7k29aa_in_process.py build_wheel /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmp3uclv7s0
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-9yue2z_2/pycairo_6e8980c547854f61b37cd69a19f0771b
#     Complete output (14 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     creating build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.py -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.pyi -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/py.typed -> build/lib.macosx-10.9-universal2-3.9/cairo
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     'pkg-config' not found.
#     Command ['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c1/36/c31a6ce9411b22a8ac0759c9b5ffda09368d5e0643450bb8ed83c271588c/PyGObject-3.32.1.tar.gz#sha256=4165d9fb4157e69c76f29e52a6d73a39a804e18ad9ef0eede15efd9c57c52bf2 (from https://pypi.org/simple/pygobject/). Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-tf2ly0uj/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-dkaop06g/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Downloading PyGObject-3.32.0.tar.gz (698 kB)
#      |████████████████████████████████| 698 kB 6.3 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-3ywrhe45/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-8vx0m2sb/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo
#        cwd: None
#   Complete output (37 lines):
#   Collecting setuptools
#     Using cached setuptools-58.0.2-py3-none-any.whl (816 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting pycairo
#     Using cached pycairo-1.20.1.tar.gz (344 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: pycairo
#     Building wheel for pycairo (PEP 517): started
#     Building wheel for pycairo (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmpokp1le90_in_process.py build_wheel /var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/tmpgdjixscd
#          cwd: /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-install-p4e41fez/pycairo_3394f357dea14c68889ef2d52dcb7428
#     Complete output (14 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-universal2-3.9
#     creating build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.py -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/__init__.pyi -> build/lib.macosx-10.9-universal2-3.9/cairo
#     copying cairo/py.typed -> build/lib.macosx-10.9-universal2-3.9/cairo
#     warning: build_py: byte-compiling is disabled, skipping.
#
#     running build_ext
#     'pkg-config' not found.
#     Command ['pkg-config', '--print-errors', '--exists', 'cairo >= 1.15.10']
#     ----------------------------------------
#     ERROR: Failed building wheel for pycairo
#   Failed to build pycairo
#   ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/0b/fd/56ac6898afc5c7f5718026103bd8f0b44714b6f79ac20d7eb8990c9a7eab/PyGObject-3.32.0.tar.gz#sha256=a4d6f6d8e688d28e07119fc83aabc6e7aad02057f48b2194089959d03654f695 (from https://pypi.org/simple/pygobject/). Command errored out with exit status 1: /Users/eduardo/.local/share/virtualenvs/eduardo-BbA8MaND/bin/python /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-standalone-pip-3ywrhe45/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/k_/5bn7s8bj3q50cjmfsm__qhlr0000gn/T/pip-build-env-8vx0m2sb/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel pycairo Check the logs for full command output.
#   Downloading PyGObject-3.30.5.tar.gz (690 kB)
#      |████████████████████████████████| 690 kB 7.4 MB/s eta 0:00:01

# %% [markdown]
# Luego, importamos algunas bibliotecas para manejo de audio, reconocimient y síntesis:

# %%
import speech_recognition as sr 
from pydub import AudioSegment
from IPython.display import Javascript, Audio
from google.colab import output
from base64 import b64decode
from io import BytesIO
import subprocess
import re
from gtts import gTTS

# %% [markdown]
# Dado que nuestro programa está corriendo en *Google Colab*, el manejo de audio no es tan directo como cuando el programa se encuentra en nuestro propio computador ya que accede directamente a los dispositivos de audio (micrófono, parlantes).
#
# Para resolver este problema, realizamos dos pasos:
# 1. Grabar el audio y almacenarlo en un archivo de sonido (se debe utilizar *JavaScript*).
# 2. Realizar el reconocimiento de voz a partir del audio previamente grabado.
#
# Para esto,  definimos la función **Grabar()**, que graba un audio utilizando un código JavaScript en el archivo temporal "*out00.wav*":

# %%
RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def Grabar(sec=5):
  display(Javascript(RECORD))
  s = output.eval_js('record(%d)' % (sec*1000))
  b = b64decode(s.split(',')[1])
  with open('audio.webm','wb') as f:
    f.write(b)
  command = ['ffmpeg', '-i', 'audio.webm', '-f', 'segment', '-segment_time', '100', 'out%02d.wav']
  subprocess.run(command,stdout=subprocess.PIPE,stdin=subprocess.PIPE)
  return('out00.wav')

# %% [markdown]
# Definimos la función **ASR()** que realiza el reconocimiento de voz propiamente tal, y que utiliza el módulo de grabado de audio, especificado previamente:

# %%
def ASR():
    texto_reconocido=""
    print("Comience a hablar..")
    # Si ejecutará el programa en su computador (NO Colab), simplemente
    # reemplace las líneas desde "WAVES=.."  hasta "try:" por las siguientes:
    #r = sr.Recognizer()                                                                                   
    #with sr.Microphone() as source:                                                                     
    #   print(".")
    #   audio = r.listen(source)   
    #   print("..")
    #try: 
    WAVES = Grabar()
    fuente = sr.AudioFile(WAVES)
    r = sr.Recognizer()
    with fuente as source:
         audio = r.record(source)                                 
    try:
         texto_reconocido = r.recognize_google(audio, language='es-es')
    except sr.UnknownValueError:
       print("No entendi el audio")
    return(texto_reconocido)

# %% [markdown]
# Luego,  definimos la función  **TTS(texto)**, que realiza la síntesis de voz en Español utilizando el método **gTTS(..)**,  a partir de un **texto**, utilizando modelos *fonéticos* pre-entrenados:

# %%
def TTS(texto):
  sound_file = 'tmp.wav'
  tts = gTTS(texto, lang="es")
  tts.save(sound_file) 
  display(Audio(sound_file,autoplay=True))

# %% [markdown]
# Finalmente, hacemos una prueba del ASR y TTS desde el programa principal. Para esto, buscamos si en la voz reconocida del usuario aparece la palabra "*auto*" en algún lugar:

# %%
texto = ASR()
print("Dijiste: ",texto)
calce = re.search("auto",texto)
if calce != None:
    TTS("Usted necesita comprar un auto..")
